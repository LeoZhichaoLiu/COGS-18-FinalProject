# %% [markdown]
# # Final Project: Playing Interactive Games
# ####  ----- By Zhichao Liu (A15639159)

# %% [markdown]
# ## Overiew
#
# This project is a game that can the user can play.
# There are two games: `1) Accumulate Number to goal`   and    `2) Guess vocabulary`
# The user can choose one of the game by entering 1 or 2.
#
# #### 1) Accumulate Number to goal:
#  During this game, the player will first be required to set up a goal number. The goal of this game is to enter
#  number in each turn and reach that goal number. The game will be played between the user and the computer.
#  In each turn, the user can first enter any integer number in range 1 to 3, any invalid input will result in
#  prompt again. After you entering, the computer will randomly input a number from 1 to 3.
#  The program will record the overall accumulation of number you and the computer enter in all turns. If you or
#  computer enter a number that cause the accumulation greater or equal to the goal number, that means you or
#  computer win the game.
#
# #### 2) Guess vocabulary:
#  Normally this game should involve two players: player 1 and player 2
#  For player 1, he or she should enter a vocabulary as string to the system. And system will record that vocabulary.
#  Then, player 2 will come and try to guess that vocabulary.
#  The system will give player 2 the hint that showing a hiding vocabulary. * indicate this letter has not been
#  guessed.
#  In each turn, player 2 can enter a single letter to guess that vocabulary. If vocabulary contains that letter,
#  the corresponding vocabulary position will change from * to that letter.
#  If the player 2 guess the whole vocabulary, which means all letters change from * to specific letter, the player
#  2 win the game.

# %% [markdown]
# # Part 1: Import the pakage
# In this project, we just use random and string pakage, so just import them at the top

# %%
# Import random and string pakage used in below functions
import random 
import string

# %% [markdown]
# # Part 2: The function to check which game the user select ( 1 or 2)
# In this function, no argument is needed. The user will enter to a loop and will see the instruction prompt
# to ask you to select the game.
# You can enter 1 or 2 to select the corresponding game. Note that any invalid selection such as 3, 0, haha will
# result in repeated prompt to ask you enter new input. Only if you select the valid game command, you can exit
# the while loop.
# After that, the function will return the result of your selection. 1 as choosing game 1, 2 as choosing game 2.

# %%
def check_which_game () :
    """
    Let user enter a loop to select which game they want to play (1 or 2).
    
    Returns
    -------
    output : String
        String indicating the choice that user make (1 or 2).
    """
    
    # Print the introducation sentences to welcome the players!
    print ("Start to play game! There are two games you can select:" )     
    print ("  1）Accumulate Number to goal            2）Guess vocabulary")
    
    # Use while loop to ask user the input command
    while (1) :
        
        # Print the instruction asking user to input command 1 or 2, and record user's input as command
        print ()
        command = input ("Please enter number 1 as first game, or 2 as second game:    ")
        
        # If command is 1, return 1 as user choose to play the first game
        if (command == "1") :    
            return 1
        
        # If command is 2, return 2 as user choose to play the second game
        elif (command == "2") :
            return 2
        
        # If command is not 1 or 2, the instruction will be prompted again until you enter 1 or 2
        else :
            continue

# %% [markdown]
# # Part 3: The functions to proceed game 1 (Accumulate Number to goal)
# The part3 is about the functions used to play the first game: Accumulate Number to goal.
# The main function is `play_game_1`, which will call `game_1_communicate` and `set_goal` in it. The
# `game_1_communicate` will call function check_1_win to check when the player or computer win the game.
#
# `set_goal` is the function to let player set the goal number, which should be in the range from 10 to 100.
# If player's input is invalid, the system will ask player to set again, until a valid goal number is set.
# This function will return goal number back.
#
# `check_1_win` is the function to check whether player or computer win the game. It require three arguments,
# goal number, accumulation, and player name. If goal is smaller or equal to accmulation, it means this player
# win the game. The system will print the different congradulation sentence based on player argument (human or
# computer). And this function will return true or false based on whether it wins.
#
# `game_1_communicate` is the function to generate a interative loop to respond player's input and set the computer
# input and see who will win. It implements `check_1_win` function.
#
# `play_game_1` is the function to summary above functions to play game 1. It will print the instruction first.
# Calling this function from other places can play this game.

# %%
def set_goal () :
    """
    Let user enter a loop to set the goal number that want to reach in game. It should be in range [10,100].
    
    Returns
    -------
    output : String
        String indicates that the goal number the user sets.
    """
    
    # Use while loop to set the goal
    while (1) :
        
            # Print instruction that which number you want to set as goal, and record that number as goal
            goal_string = input (" READY TO START? First set up the GOAL, positive integer from 10 to 100   ")
            goal = int (goal_string, 10)
            
            # If goal is not in range [10,100], continue to loop until the user enter valid goal
            if (goal < 10 or goal > 100) :         
                continue
              
            # If goal is in the range, break the loop
            else :
                break
                
    # Finally return the goal number            
    return goal

# %%
def check_1_win (goal, accumulation, player) :
    """
    Check whether the player (human or computer) win this game.
    
    Parameters
    ----------
    input: goal             An int indicating the goal number the player want to reach.
           accumulation     The int current number the palyer reaches.
           player           The string indicating the name of the user (computer or human).
           
    Returns
    -------
    output : bol
        bol indicating whether the user win the game.
    """
    
    # If accumulation is bigger or equal to goal, meaning that player win the game
    if (accumulation >= goal) :
        
        # If that player is you, print the congradulation sentence and return true
        if (player == "you") :     
            
            print ("CONGRADULATION! YOU WIN!")
            return True
        
        # If that player is computer, print the congradulation sentence and return true
        elif (player == "computer") :  
            
            print ("UNFORTUNELY, YOU LOSE! COMPUTER WIN!")
            return True
    
    # If accumulation is smaller than goal, just return false as the player is not win now.
    else :
        return False

# %%
def game_1_communicate (goal, accumulation, turn) :
    """
    Let user enter a interactive loop to play the game.
    
    Parameters
    ----------
    input: goal             An int indicating the goal number the player want to reach.
           accumulation     The int current number the palyer reaches.
           turn             The round that players play now.
           
    Returns
    -------
    output : None
    """
    
    while (1) :
        
        # In each loop, increment of turn showing which turn we are in
        turn = turn + 1
        
        # Print the current turn's information, with turn number and accumulation number and goal number
        print ()
        print ("TURN " + str (turn) +") accumulation: " + str (accumulation) + "    goal: " + str (goal) )
        print ()
        
        # Then, print the prompt to ask user input the number in this turn
        you_input_string = input (" Please enter a number from range [1,3]  ")
        you_input = int (you_input_string, 10)
        
        # Print your input to the display
        print ()
        print ("your input: " + str (you_input))
        
        # If your input is not in the rangle [1,3], you will continue the loop, but turn will remain the same
        if ( you_input < 1 or you_input > 3) :
            turn = turn - 1
            continue
        
        # Then, after you input the number, calculate the accmulation and check whether you win.
        accumulation = accumulation + you_input
        
        if (check_1_win (goal, accumulation, "you")) :
            break
        
        # Then, computer will randomly select the input number, and we calculate accumulation.
        computer_input = random.choice ([1,2,3])
        print ("computer input: " + str (computer_input))
        accumulation = accumulation + computer_input
        
        # We check whether computer win this game. If not, continue to the next turn.
        if (check_1_win (goal, accumulation, "computer")) :
            break

# %%
def play_game_1 () :
    """
    Print the instructions and implement the above functions to play the game.
    
    Returns
    -------
    output : None
    """
    
    # First, we print the game 1 instruction.
    print ()
    print ("You choose game 1: Accumulate Number to Goal!")
    print ()
    print ("In this game, you will play with the computer each turn to complete a goal.")
    print ()
    print ("1) You need to set up the goal (a positive number in range [10,100]. ")
    print ("2) Then in each turn, you can enter a number from range [1,3], invalid input causes prompt again")
    print ("   The computer will randomly pick the number in each turn.")
    print ("   the sum of your input and computer input will be accmulated")
    print ("3) Finally, if you enter a number and the accumulation reach the goal you set, YOU WIN!")
    print ("   If computer reach the goal, COMPUTER WIN!")
    print ()
    
    # We set the initial value of goal to 0, and then call function set_goal to set goal number
    goal = 0
    goal = set_goal ()
    
    # We also set accumulation and turn to 0.
    accumulation = 0
    turn = 0  
    
    # We call function game_1_communicate to enter the game process
    game_1_communicate (goal, accumulation, turn)

# %% [markdown]
# # Part 3: The functions to proceed game 2 (Guess vocabulary)
# The part3 is about the functions used to play the second game: Guess vocabulary. The main function is `play_game_2`, which will call `game_2_communicate`, `set_vocabulary` and `set_hiding_vocabulary` in it. The `game_2_communicate` will call function `check_2_win` to check when the player win the game.
#
# `set_vocabulary` is the function to let player 1 to set the vocabulary player 2 will guess. The function will record
# that vocabulary and return it.
#
# `set_hiding_vocabulary` is the function to create the hiding vocabulary, in the format like ***. The number of
# "*" is depend on the length of vocabulary. For example, if the vocabulary is cat, the hiding vocabulary is ***.
#
# `check_2_win` is the function to check whether player 2 guess that word and win. If so, it will return true. Else
# return false as not finishing game.
#
# `game_2_communicate` is the function to create a interactive loop for user to play the game. It will call `check_2_win` to determine whether end the loop.
#
# `play_game_2` is the main function to combine all above functions to play this game. It will first print the instruction. Calling this function can enter the game and play it.

# %%
def set_vocabulary () :
    """
    Let user 1 enter a loop to set the vocabulary that want the player 2 to guess.
    
    Returns
    -------
    output : String
        String indicates that the vocabulary the user 1 sets.
    """
    
    # We set the prompt instruction and record user's input as the vocabulary
    vocabulary = input ("READY TO START? Now let Player 1 enter the vocabulary:   ")
    print ()
    
    # Return that vocabulary
    return vocabulary


def set_hiding_vocabulary (vocabulary) :
    """
    Set the vocabulary provided by player 1 to a hiding string in format of ****.
    
    Parameters
    ----------
    input: vocabulary    The vocabulary that player 1 set to let player 2 to guess.
           
    Returns
    -------
    output : String
        String indicating the hiding vocabulary shown to player 2 to guess.
    """
    
    # Print the instruction to welcome the player 2
    print ("Now, invite Player 2!!")
    print()
    
    # We set the vocabulary_display as the hiding vocabulary with all *.
    vocabulary_display = "*" * len (vocabulary)
    
    # We print that hiding vocabulary and return hiding vocabulary
    print ("The vocabulary is looked like:   " + vocabulary_display)
    
    return vocabulary_display

# %%
def check_2_win (vocabulary_display) :
    """
    Check whether the player 2 win this game (guess the vocabulary).
    
    Parameters
    ----------
    input: vocabulary            The vocabulary that player 1 set to let player 2 to guess.
           vocabulary_display    The hiding string that give hint to player 2.
           
    Returns
    -------
    output : bol
        bol indicating whether the user win the game.
    """
    
    # If * is not in vocabulary_display, meaning you guess what is that word is. Congradulate to you!
    if ("*" not in vocabulary_display) :
        print ("CONGRADULATION! YOU WIN!!")
        return True
    
    # Else, you don't win now, return false
    else :
        return False

# %%
def game_2_communicate (vocabulary, vocabulary_display) :
    """
    Let user enter a interactive loop to play the game (guess what is the vocabulary).
    
    Parameters
    ----------
    input: vocabulary            The vocabulary that player 1 set to let player 2 to guess.
           vocabulary_display    The hiding string that give hint to player 2.
           
    Returns
    -------
    output : None
    """
    
    while (1) :
        
            # In while loop, ask player 2 to enter the letter.
            while (1) : 
                
                # Record that input as letter
                letter = input ("Now, please Player 2 enter the letter you think this vocabulary should contain:  ")
                
                # If letter's length is larger than 1, meaning it's not single letter, print error and continue
                if (len(letter) > 1) :
                    print ("Please enter SINGLE letter!!!")
                    print ()
                 
                # If letter is a single letter, break the while loop.
                else :
                    break
        
            # Then, we use for loop check each index of vocabulary
            for index in range (len (vocabulary)) :
                
                # If that index of vocabulary is letter user input, just replace that * with letter
                if (vocabulary[index] == letter) :
                    vocabulary_display = vocabulary_display[:index] + letter + vocabulary_display[index + 1:]
        
            # Print the current display hiding vocabulary, it should contain * and letter user input
            print ()
            print ("The new vocabulary is : " + vocabulary_display)
            
            # We call function check_2_win to see whether we finish guessing
            if (check_2_win (vocabulary_display)) :
                break

# %%
def play_game_2 () :
    """
    Print the instructions and implement the above functions to play the game.
    
    Returns
    -------
    output : None
    """

    # First we print the instruction guide to play the game 2
    print ()
    print ("You choose game 2: Guess vocabulary!")
    print ()
    print ("The goal of this game is to guess a vocabulary. It should involve two players to play")
    print ()
    print ("1) Player 1 sould enter any vocabulary that wish player 2 to guess, case matter.")
    print ("2) The system will output form like ***** to show the number of the correct vocabulary.")
    print ("3) Player 2 can guess the vocabulary by entering specific letter.")
    print ("4) The system will give hint to tell you whether the vocabulary contains your guessing letter")
    print ("   Symbol * indicate that your guessing letter doesn't exist in that position")
    print ("   If that position is your guessing letter, * will change to the letter you guess")
    print ("5) If you guess all the letter the vocabury contains, YOU WIN")
    print ()
    
    # Then we set the vocabulary and vocabulary_display according to vovabulary input
    vocabulary = set_vocabulary ()
    vocabulary_display = set_hiding_vocabulary (vocabulary)
    
    # Finally we call game_2_communicate to enter the game playing
    game_2_communicate (vocabulary, vocabulary_display)

# %% [markdown]
# # Part 4: Let's use these functions to play this game! ( Like Main function)
# This is like the main function to handle this game (playing two game based on user's choice).
#
# First we will use function `check_which_game` to see which game the player choose to play.
#
# Then, the player will call either `play_game_1` or `play_game_2` based on the choice to play the game.
#
# Note that if you want to repeat this process or try the other game, you have to first finish the current game and
# then run this cell again to start another game.
#
# Enjoy it!!

# %%
# To play the game, we first check which game the user wants to play (1 or 2)
game_to_play = check_which_game ()

# If that number is 1, just call play_game_1 to play that game 1
if (game_to_play == 1) :
    play_game_1 ()

# If that number is 2, call play_game_2 to play game 2
elif (game_to_play == 2) :
    play_game_2 ()
# Out:
# Start to play game! There are two games you can select:
#   1）Accumulate Number to goal            2）Guess vocabulary
#
# Please enter number 1 as first game, or 2 as second game:    2
#
# You choose game 2: Guess vocabulary!
#
# The goal of this game is to guess a vocabulary. It should involve two players to play
#
# 1) Player 1 sould enter any vocabulary that wish player 2 to guess, case matter.
# 2) The system will output form like ***** to show the number of the correct vocabulary.
# 3) Player 2 can guess the vocabulary by entering specific letter.
# 4) The system will give hint to tell you whether the vocabulary contains your guessing letter
#    Symbol * indicate that your guessing letter doesn't exist in that position
#    If that position is your guessing letter, * will change to the letter you guess
# 5) If you guess all the letter the vocabury contains, YOU WIN
#
# READY TO START? Now let Player 1 enter the vocabulary:   Python
#
# Now, invite Player 2!!
#
# The vocabulary is looked like:   ******
# Now, please Player 2 enter the letter you think this vocabulary should contain:  p
#
# The new vocabulary is : ******
# Now, please Player 2 enter the letter you think this vocabulary should contain:  P
#
# The new vocabulary is : P*****
# Now, please Player 2 enter the letter you think this vocabulary should contain:  y
#
# The new vocabulary is : Py****
# Now, please Player 2 enter the letter you think this vocabulary should contain:  t
#
# The new vocabulary is : Pyt***
# Now, please Player 2 enter the letter you think this vocabulary should contain:  o
#
# The new vocabulary is : Pyt*o*
# Now, please Player 2 enter the letter you think this vocabulary should contain:  n
#
# The new vocabulary is : Pyt*on
# Now, please Player 2 enter the letter you think this vocabulary should contain:  y
#
# The new vocabulary is : Pyt*on
# Now, please Player 2 enter the letter you think this vocabulary should contain:  h
#
# The new vocabulary is : Python
# CONGRADULATION! YOU WIN!!
